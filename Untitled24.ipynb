# %%
pip install pandas numpy scikit-learn matplotlib seaborn

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.cluster import KMeans
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("fake_job_postings.csv")

print(df.head())
print(df.columns)

# %%
df = df[['title', 'description', 'fraudulent']]
df = df.dropna()

# %%
df['text'] = df['title'] + " " + df['description']

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X = vectorizer.fit_transform(df['text'])
y = df['fraudulent']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_393/1076893966.py in <cell line: 0>()
#       1 vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
# ----> 2 X = vectorizer.fit_transform(df['text'])
#       3 y = df['fraudulent']
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

from scipy.sparse import hstack   # IMPORTANT for safe merging

# Load dataset
df = pd.read_csv("/content/unsupervised-learning.csv", sep='\t')

# Keep only required columns
df = df[['description', 'fraudulent']].dropna()

X = df['description']
y = df['fraudulent']

# Convert text into TF-IDF features
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# Unsupervised learning (K-Means clustering)
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_tfidf)

# Convert cluster labels into sparse column
cluster_feature = np.array(cluster_labels).reshape(-1, 1)

# Combine TF-IDF + cluster feature (HYBRID FEATURE SET)
X_final = hstack([X_tfidf, cluster_feature])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=42
)

# Supervised learning model
model = MultinomialNB()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_393/965031708.py in <cell line: 0>()
#      14
#      15 # Keep only required columns
# ---> 16 df = df[['description', 'fraudulent']].dropna()
#      17
#      18 X = df['description']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from scipy.sparse import hstack

df = pd.read_csv("fake_job_postings.csv") # IMPORTANT: Please upload 'fake_job_postings.csv' to your Colab files. You can drag and drop it into the files tab on the left, or use the folder icon -> upload button.

# Print columns (for debugging)
print("Columns:", df.columns)

# ---- AUTO COLUMN FIX ----
text_col = None
for col in df.columns:
    if "desc" in col.lower() or "text" in col.lower() or "title" in col.lower(): # Added 'title' as a potential text column
        text_col = col
        break

label_col = None
for col in df.columns:
    if "fraud" in col.lower():
        label_col = col
        break

if text_col is None or label_col is None:
    raise Exception("Could not find text or label columns in dataset")

# Keep required data
df = df[[text_col, label_col]].dropna()

X = df[text_col]
y = df[label_col]

# TF-IDF
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# KMeans clustering (unsupervised)
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_tfidf)

cluster_feature = np.array(cluster_labels).reshape(-1, 1)

# Hybrid features
X_final = hstack([X_tfidf, cluster_feature])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=42
)

# Naive Bayes
model = MultinomialNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_393/1720698845.py in <cell line: 0>()
#       9 from scipy.sparse import hstack
#      10
# ---> 11 df = pd.read_csv("fake_job_postings.csv") # IMPORTANT: Please upload 'fake_job_postings.csv' to your Colab files. You can drag and drop it into the files tab on the left, or use the folder icon -> upload button.
#      12
#      13 # Print columns (for debugging)
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e54b0f0c-e74f-4319-8ed1-4bb11494ccfb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e54b0f0c-e74f-4319-8ed1-4bb11494ccfb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from scipy.sparse import hstack

# Load dataset
# IMPORTANT: The file 'fake_job_postings.csv' is still not found.
# Please upload the *actual dataset* 'fake_job_postings.csv' to your Colab environment.
# The file 'fake-job-posting-a-hybrid-nn-classifier.ipynb' is a notebook, not the data.
# Once uploaded, it will likely be in the root directory '/content/'.
df = pd.read_csv("/content/fake-job-posting-a-hybrid.csv") # Expecting f in the root directory after upload

# Show columns (important for debugging)
print("Columns in dataset:", df.columns)

# Auto-detect text column
text_col = None
for col in df.columns:
    if "desc" in col.lower() or "text" in col.lower() or "title" in col.lower():
        text_col = col
        break

# Auto-detect label column
label_col = None
for col in df.columns:
    if "fraud" in col.lower() or "label" in col.lower():
        label_col = col
        break

if text_col is None or label_col is None:
    raise Exception("Dataset must contain text and label columns")

# Keep only required columns
df = df[[text_col, label_col]].dropna()

X = df[text_col]
y = df[label_col]

# Encode labels (if needed)
if y.dtype == 'object':
    le = LabelEncoder()
    y = le.fit_transform(y)

# TF-IDF conversion
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# KMeans clustering (unsupervised feature)
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_tfidf)

cluster_feature = np.array(cluster_labels).reshape(-1, 1)

# Combine TF-IDF + cluster feature (HYBRID INPUT)
X_final = hstack([X_tfidf, cluster_feature])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=42
)

# Neural Network Classifier (MLP)
model = MLPClassifier(
    hidden_layer_sizes=(64, 32),
    max_iter=20,
    random_state=42
)

model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_393/2815254394.py in <cell line: 0>()
#      16 # The file 'fake-job-posting-a-hybrid-nn-classifier.ipynb' is a notebook, not the data.
#      17 # Once uploaded, it will likely be in the root directory '/content/'.
# ---> 18 df = pd.read_csv("/content/fake-job-posting-a-hybrid.csv") # Expecting f in the root directory after upload
#      19
#      20 # Show columns (important for debugging)
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c6e2974-01c9-4793-90f6-1ecec1fb4da1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c6e2974-01c9-4793-90f6-1ecec1fb4da1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

from scipy.sparse import hstack

# Load dataset (after uploading to Colab)
df = pd.read_csv("/content/fake_job_postings (1).csv.zip")

# Keep only required columns
df = df[['description', 'fraudulent']].dropna()

X = df['description']
y = df['fraudulent']

# TF-IDF conversion
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# Unsupervised learning (KMeans clustering)
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_tfidf)

# Convert cluster output into feature
cluster_feature = np.array(cluster_labels).reshape(-1, 1)

# Hybrid feature set
X_final = hstack([X_tfidf, cluster_feature])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=42
)

# Neural Network model
model = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=20, random_state=42)
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_393/4019795585.py in <cell line: 0>()
#      12
#      13 # Load dataset (after uploading to Colab)
# ---> 14 df = pd.read_csv("fake_job_postings.csv")
#      15
#      16 # Keep only required columns
#
# ...
